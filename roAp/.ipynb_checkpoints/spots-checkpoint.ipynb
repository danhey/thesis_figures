# %%
import numpy as np
import starry

starry.config.lazy = False
starry.config.quiet = True

# %%
map0 = starry.Map(ydeg=1)
map0.show()

# %%
contrast = 0.25
radius = 15
map = starry.Map(ydeg=20)
# map = starry.Map(udeg=2)
# map[1] = 0.5
# map[2] = 0.25

map.spot(contrast=0.25, radius=radius, lon=0, lat=55)
map.spot(contrast=0.25, radius=20, lon=-180, lat=-55)

map.obl = 23.5
map.inc = 70.0

# %%
plt.style.use('science')

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,1, figsize=[4,4])

map.show(ax=axes, theta=300, cmap='Blues_r')

plt.savefig('opm.svg')
# map.show(ax=axes[1], projection="rect", cmap='Blues_r')

# %%
map.show(cmap='Blues_r')
